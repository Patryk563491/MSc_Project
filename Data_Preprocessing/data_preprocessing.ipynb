# %% [markdown]
# # CryoET Dataset Data Pre-Processing
#
# Requirements:
#
# - Raw tomogram in MRC format processed through Fiji ImageJ (histogram equalisation) and converted to NifTi format
#
# - Membrane segmentation CMM format (segmentation coordinates)

# %%
# Import modules

import os
import numpy as np

import nibabel as nib
import json

import gzip
import shutil

# %% [markdown]
# ### Extract 3D Patches

# %%
#modified to cater origin mismatch and works (final one for all the slices)
def extract_2D_3D_patchvolumes(raw_file, label_file, output_dir3D, start_name, patch_size=128, stride=50):
    """
    Extracts 3D patch volumes from raw and label NIfTI images and saves them with origins matched to the original volumes.

    Args:
        raw_file (str): Path to the raw NIfTI file.
        label_file (str): Path to the label NIfTI file.
        output_dir3D (str): Directory where the 3D patch volumes will be saved.
        start_name (str): Prefix for the saved patch files.
        patch_size (int, optional): Size of each patch (default is 128).
        stride (int, optional): Stride for patch extraction (default is 50).

    Returns:
        None

    Notes:
        - The created patches are in .nii.gz compressed format. Use the uncompress_nii_gz_files to create .nii files that can 
          be used in the UNet model.

    This function performs the following steps:
        1. Loads the raw and label NIfTI images.
        2. Retrieves the origin of the raw image.
        3. Creates the output directory if it doesn't exist.
        4. Iterates over each slice of the raw image.
        5. Extracts 2D patches from each slice based on the given patch size and stride.
        6. Ensures that patches are extracted from unique coordinates.
        7. Checks if the patch contains at least 50 labeled pixels.
        8. Initializes arrays for storing 3D patches.
        9. Crops the same portion across all z-slices to form 3D patches.
        10. Sets the origin of the cropped volumes to match the original volume.
        11. Saves the cropped raw and label patches as NIfTI files.
        12. Records patch information and increments the patch count.
        13. Compares and verifies the origin of each patch with the original volume.
        14. Saves patch information in a JSON file.
        15. Prints the number of saved patch files, the total number of cropped patches, and the number of patches with matched origins.
    """
    # Load the raw image and label data
    raw_img = nib.load(raw_file)
    label_img = nib.load(label_file)
    
    # Get the origin values for the original volume
    raw_origin = raw_img.affine[:3, 3]
    
    # Create the output directory for 2D patches if it doesn't exist
    if not os.path.exists(output_dir3D):
        os.makedirs(output_dir3D)

    # Initialize a list to store patch information
    patchvol_info = []

    # Keep track of unique coordinates
    unique_coordinates = set()

    # Initialize counter for the number of patch volumes cropped
    patchvol_count = 0
    origin_match_count = 0

    # Loop through each slice
    for z in range(raw_img.shape[2]):
        # Get the current slice
        raw_slice = raw_img.get_fdata()[:, :, z]
        label_slice = label_img.get_fdata()[:, :, z]

        # Loop through the image and extract patches
        for y in range(0, raw_slice.shape[0] - patch_size + 1, stride):
            for x in range(0, raw_slice.shape[1] - patch_size + 1, stride):
                # Check if the coordinates have already been processed
                if (y, x) in unique_coordinates:
                    continue

                # Extract the patch
                patch = raw_slice[y:y+patch_size, x:x+patch_size]
                patch_offset = label_slice[y:y+patch_size, x:x+patch_size]

                # Check if the patch contains at least 50 pixels of labels
                if np.sum(patch_offset == 1) < 50:
                    continue

                # Initialize arrays to store cropped raw and label volumes
                cropped_raw = np.zeros((patch_size, patch_size, 400))
                cropped_label = np.zeros((patch_size, patch_size, 400))

                # Crop the same portion across all z-slices
                for zz in range(raw_img.shape[2]):
                    cropped_raw[:, :, zz] = raw_img.get_fdata()[:, :, zz][y:y+patch_size, x:x+patch_size]
                    cropped_label[:, :, zz] = label_img.get_fdata()[:, :, zz][y:y+patch_size, x:x+patch_size]

                # Set the origin of the cropped volumes to match the origin of the original volume
                cropped_raw_affine = raw_img.affine.copy()
                cropped_raw_affine[:3, 3] = raw_origin
                
                cropped_label_affine = label_img.affine.copy()
                cropped_label_affine[:3, 3] = raw_origin

                cropped_raw_img = nib.Nifti1Image(cropped_raw, cropped_raw_affine, raw_img.header)
                cropped_label_img = nib.Nifti1Image(cropped_label, cropped_label_affine, label_img.header)

                patch_file = os.path.join(output_dir3D, f'{start_name}z{z}y{y}x{x}.nii.gz')
                offset_file = os.path.join(output_dir3D, f'{start_name}z{z}y{y}x{x}_gt.nii.gz')

                nib.save(cropped_raw_img, patch_file)
                nib.save(cropped_label_img, offset_file)

                # Store patch information
                patchvol_info.append({'z': z, 'x': x, 'y': y})

                # Add the coordinates to the unique_coordinates set
                unique_coordinates.add((y, x))

                # Increment the patch volume count
                patchvol_count += 1

                # Compare the origin values for the patch and original volume
                patch_origin = cropped_raw_img.affine[:3, 3]
                if np.array_equal(patch_origin, raw_origin):
                    origin_match_count += 1
                    #print(f"Origin values match for patch: {patch_file}")
                else:
                    print(f"Origin values mismatch for patch: {patch_file}")
                    print(f"Patch origin: {patch_origin}")
                    print(f"Original origin: {raw_origin}")

    # Save patch information as a JSON file
    patch_info_file = os.path.join(output_dir3D, f'patchvol{start_name}.json')
    with open(patch_info_file, 'w') as f:
        json.dump(patchvol_info, f)

    # Print the number of files in output_dir3D
    file_count_3D = len(os.listdir(output_dir3D))
    print(f"Number of files in output_dir3D: {file_count_3D}")

    # Print the number of patch volumes cropped
    print(f"Number of patch volumes cropped: {patchvol_count}")

    # Print the number of patch volumes with origin matched
    print(f"Number of patch volumes with origin matched: {origin_match_count}")

# %%
raw_file = r"1.1_folder/Pos_3_6_9_test_data_2/Pos_3_6_9_52Apx_rawEqualizedvolume.nii"
label_file = r"1.1_folder/Pos_3_6_9_test_data_2/Pos_3_6_9_binary_label_equalized.nii"
output_dir3D = r"1.2_folder/Pos_3_6_9_test_data_3D_patches"
start_name = "Pos_3_6_9"

extract_2D_3D_patchvolumes(raw_file = raw_file, label_file = label_file, output_dir3D = output_dir3D, start_name = start_name, patch_size=128, stride=50)
# Out:
# Number of files in output_dir3D: 647
# Number of patch volumes cropped: 323
# Number of patch volumes with origin matched: 323

# %% [markdown]
# ### Uncompress .nii.gz files and store tomogram and label patches in separate folders

# %%
def uncompress_nii_gz_files(input_dir, tomogram_output_dir, label_output_dir):
    """
    Uncompresses .nii.gz files in the input directory and stores them in the designated tomogram and label directories.

    Args:
        input_dir (str): Directory containing the compressed .nii.gz files.
        tomogram_output_dir (str): Directory to store the uncompressed tomogram .nii files.
        label_output_dir (str): Directory to store the uncompressed label .nii files.

    Returns:
        None
    """
    # Create output directories if they don't exist
    if not os.path.exists(tomogram_output_dir):
        os.makedirs(tomogram_output_dir)
    
    if not os.path.exists(label_output_dir):
        os.makedirs(label_output_dir)
    
    # Iterate through the files in the input directory
    for filename in os.listdir(input_dir):
        if filename.endswith(".nii.gz"):
            input_file_path = os.path.join(input_dir, filename)
            
            # Determine if the file is a tomogram or label based on the filename
            if filename.endswith("_gt.nii.gz"):
                output_file_path = os.path.join(label_output_dir, filename[:-3])  # Remove the .gz extension
            else:
                output_file_path = os.path.join(tomogram_output_dir, filename[:-3])  # Remove the .gz extension
            
            # Uncompress the .nii.gz file
            with gzip.open(input_file_path, 'rb') as f_in:
                with open(output_file_path, 'wb') as f_out:
                    shutil.copyfileobj(f_in, f_out)
            print(f"Uncompressed and saved {filename} to {output_file_path}")

# %%
# Define the directory paths
input_dir = "1.2_folder/Pos_3_6_9_test_data_3D_patches"
tomogram_output_dir = "1.2_folder/Pos_3_6_9_tomogram_patches"
label_output_dir = "1.2_folder/Pos_3_6_9_label_patches"

# Call the function to uncompress files and store them in the designated directories
uncompress_nii_gz_files(input_dir, tomogram_output_dir, label_output_dir)
# Out:
# Uncompressed and saved Pos_3_6_9z108y150x850.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z108y150x850.nii
# Uncompressed and saved Pos_3_6_9z108y150x850_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z108y150x850_gt.nii
# Uncompressed and saved Pos_3_6_9z108y200x850.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z108y200x850.nii
# Uncompressed and saved Pos_3_6_9z108y200x850_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z108y200x850_gt.nii
# Uncompressed and saved Pos_3_6_9z108y250x850.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z108y250x850.nii
# Uncompressed and saved Pos_3_6_9z108y250x850_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z108y250x850_gt.nii
# Uncompressed and saved Pos_3_6_9z110y100x750.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z110y100x750.nii
# Uncompressed and saved Pos_3_6_9z110y100x750_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z110y100x750_gt.nii
# Uncompressed and saved Pos_3_6_9z110y100x800.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z110y100x800.nii
# Uncompressed and saved Pos_3_6_9z110y100x800_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z110y100x800_gt.nii
# Uncompressed and saved Pos_3_6_9z110y100x850.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z110y100x850.nii
# Uncompressed and saved Pos_3_6_9z110y100x850_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z110y100x850_gt.nii
# Uncompressed and saved Pos_3_6_9z110y150x750.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z110y150x750.nii
# Uncompressed and saved Pos_3_6_9z110y150x750_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z110y150x750_gt.nii
# Uncompressed and saved Pos_3_6_9z110y150x800.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z110y150x800.nii
# Uncompressed and saved Pos_3_6_9z110y150x800_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z110y150x800_gt.nii
# Uncompressed and saved Pos_3_6_9z110y200x750.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z110y200x750.nii
# Uncompressed and saved Pos_3_6_9z110y200x750_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z110y200x750_gt.nii
# Uncompressed and saved Pos_3_6_9z110y200x800.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z110y200x800.nii
# Uncompressed and saved Pos_3_6_9z110y200x800_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z110y200x800_gt.nii
# Uncompressed and saved Pos_3_6_9z110y300x850.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z110y300x850.nii
# Uncompressed and saved Pos_3_6_9z110y300x850_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z110y300x850_gt.nii
# Uncompressed and saved Pos_3_6_9z110y50x800.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z110y50x800.nii
# Uncompressed and saved Pos_3_6_9z110y50x800_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z110y50x800_gt.nii
# Uncompressed and saved Pos_3_6_9z110y50x850.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z110y50x850.nii
# Uncompressed and saved Pos_3_6_9z110y50x850_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z110y50x850_gt.nii
# Uncompressed and saved Pos_3_6_9z112y250x800.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z112y250x800.nii
# Uncompressed and saved Pos_3_6_9z112y250x800_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z112y250x800_gt.nii
# Uncompressed and saved Pos_3_6_9z116y350x850.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z116y350x850.nii
# Uncompressed and saved Pos_3_6_9z116y350x850_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z116y350x850_gt.nii
# Uncompressed and saved Pos_3_6_9z116y750x650.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z116y750x650.nii
# Uncompressed and saved Pos_3_6_9z116y750x650_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z116y750x650_gt.nii
# Uncompressed and saved Pos_3_6_9z116y750x700.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z116y750x700.nii
# Uncompressed and saved Pos_3_6_9z116y750x700_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z116y750x700_gt.nii
# Uncompressed and saved Pos_3_6_9z116y800x600.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z116y800x600.nii
# Uncompressed and saved Pos_3_6_9z116y800x600_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z116y800x600_gt.nii
# Uncompressed and saved Pos_3_6_9z116y800x650.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z116y800x650.nii
# Uncompressed and saved Pos_3_6_9z116y800x650_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z116y800x650_gt.nii
# Uncompressed and saved Pos_3_6_9z116y800x700.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z116y800x700.nii
# Uncompressed and saved Pos_3_6_9z116y800x700_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z116y800x700_gt.nii
# Uncompressed and saved Pos_3_6_9z116y850x600.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z116y850x600.nii
# Uncompressed and saved Pos_3_6_9z116y850x600_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z116y850x600_gt.nii
# Uncompressed and saved Pos_3_6_9z116y850x650.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z116y850x650.nii
# Uncompressed and saved Pos_3_6_9z116y850x650_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z116y850x650_gt.nii
# Uncompressed and saved Pos_3_6_9z116y850x700.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z116y850x700.nii
# Uncompressed and saved Pos_3_6_9z116y850x700_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z116y850x700_gt.nii
# Uncompressed and saved Pos_3_6_9z117y350x800.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z117y350x800.nii
# Uncompressed and saved Pos_3_6_9z117y350x800_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z117y350x800_gt.nii
# Uncompressed and saved Pos_3_6_9z117y400x800.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z117y400x800.nii
# Uncompressed and saved Pos_3_6_9z117y400x800_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z117y400x800_gt.nii
# Uncompressed and saved Pos_3_6_9z117y400x850.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z117y400x850.nii
# Uncompressed and saved Pos_3_6_9z117y400x850_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z117y400x850_gt.nii
# Uncompressed and saved Pos_3_6_9z117y450x800.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z117y450x800.nii
# Uncompressed and saved Pos_3_6_9z117y450x800_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z117y450x800_gt.nii
# Uncompressed and saved Pos_3_6_9z117y450x850.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z117y450x850.nii
# Uncompressed and saved Pos_3_6_9z117y450x850_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z117y450x850_gt.nii
# Uncompressed and saved Pos_3_6_9z118y750x600.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z118y750x600.nii
# Uncompressed and saved Pos_3_6_9z118y750x600_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z118y750x600_gt.nii
# Uncompressed and saved Pos_3_6_9z118y850x800.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z118y850x800.nii
# Uncompressed and saved Pos_3_6_9z118y850x800_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z118y850x800_gt.nii
# Uncompressed and saved Pos_3_6_9z118y850x850.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z118y850x850.nii
# Uncompressed and saved Pos_3_6_9z118y850x850_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z118y850x850_gt.nii
# Uncompressed and saved Pos_3_6_9z119y850x750.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z119y850x750.nii
# Uncompressed and saved Pos_3_6_9z119y850x750_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z119y850x750_gt.nii
# Uncompressed and saved Pos_3_6_9z120y350x750.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z120y350x750.nii
# Uncompressed and saved Pos_3_6_9z120y350x750_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z120y350x750_gt.nii
# Uncompressed and saved Pos_3_6_9z120y400x750.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z120y400x750.nii
# Uncompressed and saved Pos_3_6_9z120y400x750_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z120y400x750_gt.nii
# Uncompressed and saved Pos_3_6_9z120y450x750.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z120y450x750.nii
# Uncompressed and saved Pos_3_6_9z120y450x750_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z120y450x750_gt.nii
# Uncompressed and saved Pos_3_6_9z120y500x750.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z120y500x750.nii
# Uncompressed and saved Pos_3_6_9z120y500x750_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z120y500x750_gt.nii
# Uncompressed and saved Pos_3_6_9z120y500x800.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z120y500x800.nii
# Uncompressed and saved Pos_3_6_9z120y500x800_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z120y500x800_gt.nii
# Uncompressed and saved Pos_3_6_9z120y500x850.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z120y500x850.nii
# Uncompressed and saved Pos_3_6_9z120y500x850_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z120y500x850_gt.nii
# Uncompressed and saved Pos_3_6_9z122y500x700.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z122y500x700.nii
# Uncompressed and saved Pos_3_6_9z122y500x700_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z122y500x700_gt.nii
# Uncompressed and saved Pos_3_6_9z122y50x750.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z122y50x750.nii
# Uncompressed and saved Pos_3_6_9z122y50x750_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z122y50x750_gt.nii
# Uncompressed and saved Pos_3_6_9z122y550x700.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z122y550x700.nii
# Uncompressed and saved Pos_3_6_9z122y550x700_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z122y550x700_gt.nii
# Uncompressed and saved Pos_3_6_9z122y550x750.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z122y550x750.nii
# Uncompressed and saved Pos_3_6_9z122y550x750_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z122y550x750_gt.nii
# Uncompressed and saved Pos_3_6_9z122y550x800.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z122y550x800.nii
# Uncompressed and saved Pos_3_6_9z122y550x800_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z122y550x800_gt.nii
# Uncompressed and saved Pos_3_6_9z122y600x700.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z122y600x700.nii
# Uncompressed and saved Pos_3_6_9z122y600x700_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z122y600x700_gt.nii
# Uncompressed and saved Pos_3_6_9z122y600x750.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z122y600x750.nii
# Uncompressed and saved Pos_3_6_9z122y600x750_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z122y600x750_gt.nii
# Uncompressed and saved Pos_3_6_9z122y600x800.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z122y600x800.nii
# Uncompressed and saved Pos_3_6_9z122y600x800_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z122y600x800_gt.nii
# Uncompressed and saved Pos_3_6_9z124y300x800.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z124y300x800.nii
# Uncompressed and saved Pos_3_6_9z124y300x800_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z124y300x800_gt.nii
# Uncompressed and saved Pos_3_6_9z125y250x700.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z125y250x700.nii
# Uncompressed and saved Pos_3_6_9z125y250x700_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z125y250x700_gt.nii
# Uncompressed and saved Pos_3_6_9z125y250x750.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z125y250x750.nii
# Uncompressed and saved Pos_3_6_9z125y250x750_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z125y250x750_gt.nii
# Uncompressed and saved Pos_3_6_9z125y300x700.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z125y300x700.nii
# Uncompressed and saved Pos_3_6_9z125y300x700_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z125y300x700_gt.nii
# Uncompressed and saved Pos_3_6_9z125y300x750.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z125y300x750.nii
# Uncompressed and saved Pos_3_6_9z125y300x750_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z125y300x750_gt.nii
# Uncompressed and saved Pos_3_6_9z125y350x700.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z125y350x700.nii
# Uncompressed and saved Pos_3_6_9z125y350x700_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z125y350x700_gt.nii
# Uncompressed and saved Pos_3_6_9z125y400x700.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z125y400x700.nii
# Uncompressed and saved Pos_3_6_9z125y400x700_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z125y400x700_gt.nii
# Uncompressed and saved Pos_3_6_9z126y750x550.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z126y750x550.nii
# Uncompressed and saved Pos_3_6_9z126y750x550_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z126y750x550_gt.nii
# Uncompressed and saved Pos_3_6_9z126y800x550.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z126y800x550.nii
# Uncompressed and saved Pos_3_6_9z126y800x550_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z126y800x550_gt.nii
# Uncompressed and saved Pos_3_6_9z127y550x850.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z127y550x850.nii
# Uncompressed and saved Pos_3_6_9z127y550x850_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z127y550x850_gt.nii
# Uncompressed and saved Pos_3_6_9z127y600x600.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z127y600x600.nii
# Uncompressed and saved Pos_3_6_9z127y600x600_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z127y600x600_gt.nii
# Uncompressed and saved Pos_3_6_9z127y600x650.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z127y600x650.nii
# Uncompressed and saved Pos_3_6_9z127y600x650_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z127y600x650_gt.nii
# Uncompressed and saved Pos_3_6_9z127y600x850.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z127y600x850.nii
# Uncompressed and saved Pos_3_6_9z127y600x850_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z127y600x850_gt.nii
# Uncompressed and saved Pos_3_6_9z127y650x600.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z127y650x600.nii
# Uncompressed and saved Pos_3_6_9z127y650x600_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z127y650x600_gt.nii
# Uncompressed and saved Pos_3_6_9z127y650x650.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z127y650x650.nii
# Uncompressed and saved Pos_3_6_9z127y650x650_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z127y650x650_gt.nii
# Uncompressed and saved Pos_3_6_9z127y650x700.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z127y650x700.nii
# Uncompressed and saved Pos_3_6_9z127y650x700_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z127y650x700_gt.nii
# Uncompressed and saved Pos_3_6_9z127y650x750.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z127y650x750.nii
# Uncompressed and saved Pos_3_6_9z127y650x750_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z127y650x750_gt.nii
# Uncompressed and saved Pos_3_6_9z127y650x800.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z127y650x800.nii
# Uncompressed and saved Pos_3_6_9z127y650x800_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z127y650x800_gt.nii
# Uncompressed and saved Pos_3_6_9z127y650x850.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z127y650x850.nii
# Uncompressed and saved Pos_3_6_9z127y650x850_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z127y650x850_gt.nii
# Uncompressed and saved Pos_3_6_9z127y700x600.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z127y700x600.nii
# Uncompressed and saved Pos_3_6_9z127y700x600_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z127y700x600_gt.nii
# Uncompressed and saved Pos_3_6_9z127y700x650.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z127y700x650.nii
# Uncompressed and saved Pos_3_6_9z127y700x650_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z127y700x650_gt.nii
# Uncompressed and saved Pos_3_6_9z127y700x700.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z127y700x700.nii
# Uncompressed and saved Pos_3_6_9z127y700x700_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z127y700x700_gt.nii
# Uncompressed and saved Pos_3_6_9z127y700x750.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z127y700x750.nii
# Uncompressed and saved Pos_3_6_9z127y700x750_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z127y700x750_gt.nii
# Uncompressed and saved Pos_3_6_9z127y700x800.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z127y700x800.nii
# Uncompressed and saved Pos_3_6_9z127y700x800_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z127y700x800_gt.nii
# Uncompressed and saved Pos_3_6_9z127y850x550.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z127y850x550.nii
# Uncompressed and saved Pos_3_6_9z127y850x550_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z127y850x550_gt.nii
# Uncompressed and saved Pos_3_6_9z128y750x750.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z128y750x750.nii
# Uncompressed and saved Pos_3_6_9z128y750x750_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z128y750x750_gt.nii
# Uncompressed and saved Pos_3_6_9z131y0x450.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z131y0x450.nii
# Uncompressed and saved Pos_3_6_9z131y0x450_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z131y0x450_gt.nii
# Uncompressed and saved Pos_3_6_9z131y0x500.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z131y0x500.nii
# Uncompressed and saved Pos_3_6_9z131y0x500_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z131y0x500_gt.nii
# Uncompressed and saved Pos_3_6_9z131y0x550.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z131y0x550.nii
# Uncompressed and saved Pos_3_6_9z131y0x550_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z131y0x550_gt.nii
# Uncompressed and saved Pos_3_6_9z131y100x450.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z131y100x450.nii
# Uncompressed and saved Pos_3_6_9z131y100x450_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z131y100x450_gt.nii
# Uncompressed and saved Pos_3_6_9z131y100x500.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z131y100x500.nii
# Uncompressed and saved Pos_3_6_9z131y100x500_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z131y100x500_gt.nii
# Uncompressed and saved Pos_3_6_9z131y100x550.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z131y100x550.nii
# Uncompressed and saved Pos_3_6_9z131y100x550_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z131y100x550_gt.nii
# Uncompressed and saved Pos_3_6_9z131y150x450.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z131y150x450.nii
# Uncompressed and saved Pos_3_6_9z131y150x450_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z131y150x450_gt.nii
# Uncompressed and saved Pos_3_6_9z131y150x500.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z131y150x500.nii
# Uncompressed and saved Pos_3_6_9z131y150x500_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z131y150x500_gt.nii
# Uncompressed and saved Pos_3_6_9z131y150x550.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z131y150x550.nii
# Uncompressed and saved Pos_3_6_9z131y150x550_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z131y150x550_gt.nii
# Uncompressed and saved Pos_3_6_9z131y50x450.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z131y50x450.nii
# Uncompressed and saved Pos_3_6_9z131y50x450_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z131y50x450_gt.nii
# Uncompressed and saved Pos_3_6_9z131y50x500.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z131y50x500.nii
# Uncompressed and saved Pos_3_6_9z131y50x500_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z131y50x500_gt.nii
# Uncompressed and saved Pos_3_6_9z131y50x550.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z131y50x550.nii
# Uncompressed and saved Pos_3_6_9z131y50x550_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z131y50x550_gt.nii
# Uncompressed and saved Pos_3_6_9z131y800x800.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z131y800x800.nii
# Uncompressed and saved Pos_3_6_9z131y800x800_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z131y800x800_gt.nii
# Uncompressed and saved Pos_3_6_9z131y800x850.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z131y800x850.nii
# Uncompressed and saved Pos_3_6_9z131y800x850_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z131y800x850_gt.nii
# Uncompressed and saved Pos_3_6_9z132y0x600.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z132y0x600.nii
# Uncompressed and saved Pos_3_6_9z132y0x600_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z132y0x600_gt.nii
# Uncompressed and saved Pos_3_6_9z132y0x650.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z132y0x650.nii
# Uncompressed and saved Pos_3_6_9z132y0x650_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z132y0x650_gt.nii
# Uncompressed and saved Pos_3_6_9z132y0x700.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z132y0x700.nii
# Uncompressed and saved Pos_3_6_9z132y0x700_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z132y0x700_gt.nii
# Uncompressed and saved Pos_3_6_9z132y0x750.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z132y0x750.nii
# Uncompressed and saved Pos_3_6_9z132y0x750_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z132y0x750_gt.nii
# Uncompressed and saved Pos_3_6_9z132y0x800.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z132y0x800.nii
# Uncompressed and saved Pos_3_6_9z132y0x800_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z132y0x800_gt.nii
# Uncompressed and saved Pos_3_6_9z132y0x850.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z132y0x850.nii
# Uncompressed and saved Pos_3_6_9z132y0x850_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z132y0x850_gt.nii
# Uncompressed and saved Pos_3_6_9z132y100x600.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z132y100x600.nii
# Uncompressed and saved Pos_3_6_9z132y100x600_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z132y100x600_gt.nii
# Uncompressed and saved Pos_3_6_9z132y100x650.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z132y100x650.nii
# Uncompressed and saved Pos_3_6_9z132y100x650_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z132y100x650_gt.nii
# Uncompressed and saved Pos_3_6_9z132y100x700.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z132y100x700.nii
# Uncompressed and saved Pos_3_6_9z132y100x700_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z132y100x700_gt.nii
# Uncompressed and saved Pos_3_6_9z132y150x600.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z132y150x600.nii
# Uncompressed and saved Pos_3_6_9z132y150x600_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z132y150x600_gt.nii
# Uncompressed and saved Pos_3_6_9z132y150x650.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z132y150x650.nii
# Uncompressed and saved Pos_3_6_9z132y150x650_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z132y150x650_gt.nii
# Uncompressed and saved Pos_3_6_9z132y150x700.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z132y150x700.nii
# Uncompressed and saved Pos_3_6_9z132y150x700_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z132y150x700_gt.nii
# Uncompressed and saved Pos_3_6_9z132y200x500.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z132y200x500.nii
# Uncompressed and saved Pos_3_6_9z132y200x500_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z132y200x500_gt.nii
# Uncompressed and saved Pos_3_6_9z132y200x550.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z132y200x550.nii
# Uncompressed and saved Pos_3_6_9z132y200x550_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z132y200x550_gt.nii
# Uncompressed and saved Pos_3_6_9z132y200x600.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z132y200x600.nii
# Uncompressed and saved Pos_3_6_9z132y200x600_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z132y200x600_gt.nii
# Uncompressed and saved Pos_3_6_9z132y200x650.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z132y200x650.nii
# Uncompressed and saved Pos_3_6_9z132y200x650_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z132y200x650_gt.nii
# Uncompressed and saved Pos_3_6_9z132y200x700.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z132y200x700.nii
# Uncompressed and saved Pos_3_6_9z132y200x700_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z132y200x700_gt.nii
# Uncompressed and saved Pos_3_6_9z132y250x600.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z132y250x600.nii
# Uncompressed and saved Pos_3_6_9z132y250x600_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z132y250x600_gt.nii
# Uncompressed and saved Pos_3_6_9z132y250x650.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z132y250x650.nii
# Uncompressed and saved Pos_3_6_9z132y250x650_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z132y250x650_gt.nii
# Uncompressed and saved Pos_3_6_9z132y50x600.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z132y50x600.nii
# Uncompressed and saved Pos_3_6_9z132y50x600_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z132y50x600_gt.nii
# Uncompressed and saved Pos_3_6_9z132y50x650.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z132y50x650.nii
# Uncompressed and saved Pos_3_6_9z132y50x650_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z132y50x650_gt.nii
# Uncompressed and saved Pos_3_6_9z132y50x700.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z132y50x700.nii
# Uncompressed and saved Pos_3_6_9z132y50x700_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z132y50x700_gt.nii
# Uncompressed and saved Pos_3_6_9z132y700x850.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z132y700x850.nii
# Uncompressed and saved Pos_3_6_9z132y700x850_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z132y700x850_gt.nii
# Uncompressed and saved Pos_3_6_9z132y750x800.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z132y750x800.nii
# Uncompressed and saved Pos_3_6_9z132y750x800_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z132y750x800_gt.nii
# Uncompressed and saved Pos_3_6_9z132y750x850.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z132y750x850.nii
# Uncompressed and saved Pos_3_6_9z132y750x850_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z132y750x850_gt.nii
# Uncompressed and saved Pos_3_6_9z132y800x750.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z132y800x750.nii
# Uncompressed and saved Pos_3_6_9z132y800x750_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z132y800x750_gt.nii
# Uncompressed and saved Pos_3_6_9z133y650x550.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z133y650x550.nii
# Uncompressed and saved Pos_3_6_9z133y650x550_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z133y650x550_gt.nii
# Uncompressed and saved Pos_3_6_9z133y700x550.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z133y700x550.nii
# Uncompressed and saved Pos_3_6_9z133y700x550_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z133y700x550_gt.nii
# Uncompressed and saved Pos_3_6_9z134y300x600.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z134y300x600.nii
# Uncompressed and saved Pos_3_6_9z134y300x600_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z134y300x600_gt.nii
# Uncompressed and saved Pos_3_6_9z134y300x650.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z134y300x650.nii
# Uncompressed and saved Pos_3_6_9z134y300x650_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z134y300x650_gt.nii
# Uncompressed and saved Pos_3_6_9z134y350x600.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z134y350x600.nii
# Uncompressed and saved Pos_3_6_9z134y350x600_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z134y350x600_gt.nii
# Uncompressed and saved Pos_3_6_9z134y350x650.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z134y350x650.nii
# Uncompressed and saved Pos_3_6_9z134y350x650_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z134y350x650_gt.nii
# Uncompressed and saved Pos_3_6_9z135y100x400.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z135y100x400.nii
# Uncompressed and saved Pos_3_6_9z135y100x400_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z135y100x400_gt.nii
# Uncompressed and saved Pos_3_6_9z135y150x400.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z135y150x400.nii
# Uncompressed and saved Pos_3_6_9z135y150x400_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z135y150x400_gt.nii
# Uncompressed and saved Pos_3_6_9z135y250x550.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z135y250x550.nii
# Uncompressed and saved Pos_3_6_9z135y250x550_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z135y250x550_gt.nii
# Uncompressed and saved Pos_3_6_9z135y300x500.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z135y300x500.nii
# Uncompressed and saved Pos_3_6_9z135y300x500_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z135y300x500_gt.nii
# Uncompressed and saved Pos_3_6_9z135y300x550.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z135y300x550.nii
# Uncompressed and saved Pos_3_6_9z135y300x550_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z135y300x550_gt.nii
# Uncompressed and saved Pos_3_6_9z135y350x500.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z135y350x500.nii
# Uncompressed and saved Pos_3_6_9z135y350x500_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z135y350x500_gt.nii
# Uncompressed and saved Pos_3_6_9z135y350x550.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z135y350x550.nii
# Uncompressed and saved Pos_3_6_9z135y350x550_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z135y350x550_gt.nii
# Uncompressed and saved Pos_3_6_9z135y400x500.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z135y400x500.nii
# Uncompressed and saved Pos_3_6_9z135y400x500_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z135y400x500_gt.nii
# Uncompressed and saved Pos_3_6_9z135y400x550.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z135y400x550.nii
# Uncompressed and saved Pos_3_6_9z135y400x550_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z135y400x550_gt.nii
# Uncompressed and saved Pos_3_6_9z135y400x600.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z135y400x600.nii
# Uncompressed and saved Pos_3_6_9z135y400x600_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z135y400x600_gt.nii
# Uncompressed and saved Pos_3_6_9z135y400x650.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z135y400x650.nii
# Uncompressed and saved Pos_3_6_9z135y400x650_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z135y400x650_gt.nii
# Uncompressed and saved Pos_3_6_9z135y450x550.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z135y450x550.nii
# Uncompressed and saved Pos_3_6_9z135y450x550_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z135y450x550_gt.nii
# Uncompressed and saved Pos_3_6_9z135y450x600.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z135y450x600.nii
# Uncompressed and saved Pos_3_6_9z135y450x600_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z135y450x600_gt.nii
# Uncompressed and saved Pos_3_6_9z135y450x650.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z135y450x650.nii
# Uncompressed and saved Pos_3_6_9z135y450x650_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z135y450x650_gt.nii
# Uncompressed and saved Pos_3_6_9z135y50x400.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z135y50x400.nii
# Uncompressed and saved Pos_3_6_9z135y50x400_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z135y50x400_gt.nii
# Uncompressed and saved Pos_3_6_9z136y0x400.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z136y0x400.nii
# Uncompressed and saved Pos_3_6_9z136y0x400_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z136y0x400_gt.nii
# Uncompressed and saved Pos_3_6_9z137y100x350.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y100x350.nii
# Uncompressed and saved Pos_3_6_9z137y100x350_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y100x350_gt.nii
# Uncompressed and saved Pos_3_6_9z137y150x350.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y150x350.nii
# Uncompressed and saved Pos_3_6_9z137y150x350_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y150x350_gt.nii
# Uncompressed and saved Pos_3_6_9z137y450x700.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y450x700.nii
# Uncompressed and saved Pos_3_6_9z137y450x700_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y450x700_gt.nii
# Uncompressed and saved Pos_3_6_9z137y600x300.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y600x300.nii
# Uncompressed and saved Pos_3_6_9z137y600x300_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y600x300_gt.nii
# Uncompressed and saved Pos_3_6_9z137y600x350.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y600x350.nii
# Uncompressed and saved Pos_3_6_9z137y600x350_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y600x350_gt.nii
# Uncompressed and saved Pos_3_6_9z137y600x400.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y600x400.nii
# Uncompressed and saved Pos_3_6_9z137y600x400_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y600x400_gt.nii
# Uncompressed and saved Pos_3_6_9z137y600x450.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y600x450.nii
# Uncompressed and saved Pos_3_6_9z137y600x450_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y600x450_gt.nii
# Uncompressed and saved Pos_3_6_9z137y600x500.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y600x500.nii
# Uncompressed and saved Pos_3_6_9z137y600x500_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y600x500_gt.nii
# Uncompressed and saved Pos_3_6_9z137y600x550.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y600x550.nii
# Uncompressed and saved Pos_3_6_9z137y600x550_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y600x550_gt.nii
# Uncompressed and saved Pos_3_6_9z137y650x200.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y650x200.nii
# Uncompressed and saved Pos_3_6_9z137y650x200_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y650x200_gt.nii
# Uncompressed and saved Pos_3_6_9z137y650x250.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y650x250.nii
# Uncompressed and saved Pos_3_6_9z137y650x250_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y650x250_gt.nii
# Uncompressed and saved Pos_3_6_9z137y650x300.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y650x300.nii
# Uncompressed and saved Pos_3_6_9z137y650x300_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y650x300_gt.nii
# Uncompressed and saved Pos_3_6_9z137y650x350.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y650x350.nii
# Uncompressed and saved Pos_3_6_9z137y650x350_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y650x350_gt.nii
# Uncompressed and saved Pos_3_6_9z137y650x400.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y650x400.nii
# Uncompressed and saved Pos_3_6_9z137y650x400_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y650x400_gt.nii
# Uncompressed and saved Pos_3_6_9z137y650x450.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y650x450.nii
# Uncompressed and saved Pos_3_6_9z137y650x450_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y650x450_gt.nii
# Uncompressed and saved Pos_3_6_9z137y650x500.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y650x500.nii
# Uncompressed and saved Pos_3_6_9z137y650x500_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y650x500_gt.nii
# Uncompressed and saved Pos_3_6_9z137y700x200.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y700x200.nii
# Uncompressed and saved Pos_3_6_9z137y700x200_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y700x200_gt.nii
# Uncompressed and saved Pos_3_6_9z137y700x250.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y700x250.nii
# Uncompressed and saved Pos_3_6_9z137y700x250_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y700x250_gt.nii
# Uncompressed and saved Pos_3_6_9z137y700x300.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y700x300.nii
# Uncompressed and saved Pos_3_6_9z137y700x300_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y700x300_gt.nii
# Uncompressed and saved Pos_3_6_9z137y700x350.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y700x350.nii
# Uncompressed and saved Pos_3_6_9z137y700x350_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y700x350_gt.nii
# Uncompressed and saved Pos_3_6_9z137y700x400.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y700x400.nii
# Uncompressed and saved Pos_3_6_9z137y700x400_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y700x400_gt.nii
# Uncompressed and saved Pos_3_6_9z137y700x450.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y700x450.nii
# Uncompressed and saved Pos_3_6_9z137y700x450_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y700x450_gt.nii
# Uncompressed and saved Pos_3_6_9z137y700x500.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y700x500.nii
# Uncompressed and saved Pos_3_6_9z137y700x500_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y700x500_gt.nii
# Uncompressed and saved Pos_3_6_9z137y750x200.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y750x200.nii
# Uncompressed and saved Pos_3_6_9z137y750x200_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y750x200_gt.nii
# Uncompressed and saved Pos_3_6_9z137y750x250.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y750x250.nii
# Uncompressed and saved Pos_3_6_9z137y750x250_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y750x250_gt.nii
# Uncompressed and saved Pos_3_6_9z137y750x300.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y750x300.nii
# Uncompressed and saved Pos_3_6_9z137y750x300_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y750x300_gt.nii
# Uncompressed and saved Pos_3_6_9z137y800x200.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y800x200.nii
# Uncompressed and saved Pos_3_6_9z137y800x200_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y800x200_gt.nii
# Uncompressed and saved Pos_3_6_9z137y800x250.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y800x250.nii
# Uncompressed and saved Pos_3_6_9z137y800x250_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y800x250_gt.nii
# Uncompressed and saved Pos_3_6_9z137y800x300.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y800x300.nii
# Uncompressed and saved Pos_3_6_9z137y800x300_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y800x300_gt.nii
# Uncompressed and saved Pos_3_6_9z137y800x400.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y800x400.nii
# Uncompressed and saved Pos_3_6_9z137y800x400_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y800x400_gt.nii
# Uncompressed and saved Pos_3_6_9z137y800x450.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y800x450.nii
# Uncompressed and saved Pos_3_6_9z137y800x450_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y800x450_gt.nii
# Uncompressed and saved Pos_3_6_9z137y800x500.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y800x500.nii
# Uncompressed and saved Pos_3_6_9z137y800x500_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y800x500_gt.nii
# Uncompressed and saved Pos_3_6_9z137y850x200.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y850x200.nii
# Uncompressed and saved Pos_3_6_9z137y850x200_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y850x200_gt.nii
# Uncompressed and saved Pos_3_6_9z137y850x250.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y850x250.nii
# Uncompressed and saved Pos_3_6_9z137y850x250_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y850x250_gt.nii
# Uncompressed and saved Pos_3_6_9z137y850x300.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y850x300.nii
# Uncompressed and saved Pos_3_6_9z137y850x300_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y850x300_gt.nii
# Uncompressed and saved Pos_3_6_9z137y850x400.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y850x400.nii
# Uncompressed and saved Pos_3_6_9z137y850x400_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y850x400_gt.nii
# Uncompressed and saved Pos_3_6_9z137y850x450.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y850x450.nii
# Uncompressed and saved Pos_3_6_9z137y850x450_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y850x450_gt.nii
# Uncompressed and saved Pos_3_6_9z137y850x500.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z137y850x500.nii
# Uncompressed and saved Pos_3_6_9z137y850x500_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z137y850x500_gt.nii
# Uncompressed and saved Pos_3_6_9z138y550x600.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z138y550x600.nii
# Uncompressed and saved Pos_3_6_9z138y550x600_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z138y550x600_gt.nii
# Uncompressed and saved Pos_3_6_9z138y550x650.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z138y550x650.nii
# Uncompressed and saved Pos_3_6_9z138y550x650_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z138y550x650_gt.nii
# Uncompressed and saved Pos_3_6_9z138y600x250.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z138y600x250.nii
# Uncompressed and saved Pos_3_6_9z138y600x250_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z138y600x250_gt.nii
# Uncompressed and saved Pos_3_6_9z138y800x350.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z138y800x350.nii
# Uncompressed and saved Pos_3_6_9z138y800x350_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z138y800x350_gt.nii
# Uncompressed and saved Pos_3_6_9z138y850x350.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z138y850x350.nii
# Uncompressed and saved Pos_3_6_9z138y850x350_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z138y850x350_gt.nii
# Uncompressed and saved Pos_3_6_9z140y750x350.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z140y750x350.nii
# Uncompressed and saved Pos_3_6_9z140y750x350_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z140y750x350_gt.nii
# Uncompressed and saved Pos_3_6_9z140y750x400.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z140y750x400.nii
# Uncompressed and saved Pos_3_6_9z140y750x400_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z140y750x400_gt.nii
# Uncompressed and saved Pos_3_6_9z140y750x450.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z140y750x450.nii
# Uncompressed and saved Pos_3_6_9z140y750x450_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z140y750x450_gt.nii
# Uncompressed and saved Pos_3_6_9z141y750x100.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z141y750x100.nii
# Uncompressed and saved Pos_3_6_9z141y750x100_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z141y750x100_gt.nii
# Uncompressed and saved Pos_3_6_9z141y750x150.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z141y750x150.nii
# Uncompressed and saved Pos_3_6_9z141y750x150_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z141y750x150_gt.nii
# Uncompressed and saved Pos_3_6_9z141y750x50.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z141y750x50.nii
# Uncompressed and saved Pos_3_6_9z141y750x50_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z141y750x50_gt.nii
# Uncompressed and saved Pos_3_6_9z141y800x100.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z141y800x100.nii
# Uncompressed and saved Pos_3_6_9z141y800x100_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z141y800x100_gt.nii
# Uncompressed and saved Pos_3_6_9z141y800x150.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z141y800x150.nii
# Uncompressed and saved Pos_3_6_9z141y800x150_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z141y800x150_gt.nii
# Uncompressed and saved Pos_3_6_9z141y800x50.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z141y800x50.nii
# Uncompressed and saved Pos_3_6_9z141y800x50_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z141y800x50_gt.nii
# Uncompressed and saved Pos_3_6_9z141y850x100.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z141y850x100.nii
# Uncompressed and saved Pos_3_6_9z141y850x100_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z141y850x100_gt.nii
# Uncompressed and saved Pos_3_6_9z141y850x150.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z141y850x150.nii
# Uncompressed and saved Pos_3_6_9z141y850x150_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z141y850x150_gt.nii
# Uncompressed and saved Pos_3_6_9z141y850x50.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z141y850x50.nii
# Uncompressed and saved Pos_3_6_9z141y850x50_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z141y850x50_gt.nii
# Uncompressed and saved Pos_3_6_9z143y200x400.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z143y200x400.nii
# Uncompressed and saved Pos_3_6_9z143y200x400_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z143y200x400_gt.nii
# Uncompressed and saved Pos_3_6_9z143y200x450.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z143y200x450.nii
# Uncompressed and saved Pos_3_6_9z143y200x450_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z143y200x450_gt.nii
# Uncompressed and saved Pos_3_6_9z143y250x350.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z143y250x350.nii
# Uncompressed and saved Pos_3_6_9z143y250x350_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z143y250x350_gt.nii
# Uncompressed and saved Pos_3_6_9z143y250x400.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z143y250x400.nii
# Uncompressed and saved Pos_3_6_9z143y250x400_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z143y250x400_gt.nii
# Uncompressed and saved Pos_3_6_9z143y250x450.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z143y250x450.nii
# Uncompressed and saved Pos_3_6_9z143y250x450_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z143y250x450_gt.nii
# Uncompressed and saved Pos_3_6_9z143y250x500.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z143y250x500.nii
# Uncompressed and saved Pos_3_6_9z143y250x500_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z143y250x500_gt.nii
# Uncompressed and saved Pos_3_6_9z143y300x350.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z143y300x350.nii
# Uncompressed and saved Pos_3_6_9z143y300x350_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z143y300x350_gt.nii
# Uncompressed and saved Pos_3_6_9z143y300x400.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z143y300x400.nii
# Uncompressed and saved Pos_3_6_9z143y300x400_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z143y300x400_gt.nii
# Uncompressed and saved Pos_3_6_9z143y300x450.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z143y300x450.nii
# Uncompressed and saved Pos_3_6_9z143y300x450_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z143y300x450_gt.nii
# Uncompressed and saved Pos_3_6_9z144y200x350.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z144y200x350.nii
# Uncompressed and saved Pos_3_6_9z144y200x350_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z144y200x350_gt.nii
# Uncompressed and saved Pos_3_6_9z144y750x0.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z144y750x0.nii
# ...
# Uncompressed and saved Pos_3_6_9z147y450x50.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z147y450x50.nii
# Uncompressed and saved Pos_3_6_9z147y450x50_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z147y450x50_gt.nii
# Uncompressed and saved Pos_3_6_9z147y500x0.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z147y500x0.nii
# Uncompressed and saved Pos_3_6_9z147y500x0_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z147y500x0_gt.nii
# Uncompressed and saved Pos_3_6_9z147y500x100.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z147y500x100.nii
# Uncompressed and saved Pos_3_6_9z147y500x100_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z147y500x100_gt.nii
# Uncompressed and saved Pos_3_6_9z147y500x50.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z147y500x50.nii
# Uncompressed and saved Pos_3_6_9z147y500x50_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z147y500x50_gt.nii
# Uncompressed and saved Pos_3_6_9z147y50x0.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z147y50x0.nii
# Uncompressed and saved Pos_3_6_9z147y50x0_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z147y50x0_gt.nii
# Uncompressed and saved Pos_3_6_9z147y50x50.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z147y50x50.nii
# Uncompressed and saved Pos_3_6_9z147y50x50_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z147y50x50_gt.nii
# Uncompressed and saved Pos_3_6_9z149y400x150.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z149y400x150.nii
# Uncompressed and saved Pos_3_6_9z149y400x150_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z149y400x150_gt.nii
# Uncompressed and saved Pos_3_6_9z150y400x200.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z150y400x200.nii
# Uncompressed and saved Pos_3_6_9z150y400x200_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z150y400x200_gt.nii
# Uncompressed and saved Pos_3_6_9z150y400x250.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z150y400x250.nii
# Uncompressed and saved Pos_3_6_9z150y400x250_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z150y400x250_gt.nii
# Uncompressed and saved Pos_3_6_9z150y450x150.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z150y450x150.nii
# Uncompressed and saved Pos_3_6_9z150y450x150_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z150y450x150_gt.nii
# Uncompressed and saved Pos_3_6_9z150y450x200.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z150y450x200.nii
# Uncompressed and saved Pos_3_6_9z150y450x200_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z150y450x200_gt.nii
# Uncompressed and saved Pos_3_6_9z150y450x250.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z150y450x250.nii
# Uncompressed and saved Pos_3_6_9z150y450x250_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z150y450x250_gt.nii
# Uncompressed and saved Pos_3_6_9z150y500x150.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z150y500x150.nii
# Uncompressed and saved Pos_3_6_9z150y500x150_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z150y500x150_gt.nii
# Uncompressed and saved Pos_3_6_9z150y500x200.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z150y500x200.nii
# Uncompressed and saved Pos_3_6_9z150y500x200_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z150y500x200_gt.nii
# Uncompressed and saved Pos_3_6_9z151y550x0.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z151y550x0.nii
# Uncompressed and saved Pos_3_6_9z151y550x0_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z151y550x0_gt.nii
# Uncompressed and saved Pos_3_6_9z151y550x100.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z151y550x100.nii
# Uncompressed and saved Pos_3_6_9z151y550x100_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z151y550x100_gt.nii
# Uncompressed and saved Pos_3_6_9z151y550x50.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z151y550x50.nii
# Uncompressed and saved Pos_3_6_9z151y550x50_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z151y550x50_gt.nii
# Uncompressed and saved Pos_3_6_9z151y600x0.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z151y600x0.nii
# Uncompressed and saved Pos_3_6_9z151y600x0_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z151y600x0_gt.nii
# Uncompressed and saved Pos_3_6_9z151y600x100.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z151y600x100.nii
# Uncompressed and saved Pos_3_6_9z151y600x100_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z151y600x100_gt.nii
# Uncompressed and saved Pos_3_6_9z151y600x50.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z151y600x50.nii
# Uncompressed and saved Pos_3_6_9z151y600x50_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z151y600x50_gt.nii
# Uncompressed and saved Pos_3_6_9z151y650x100.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z151y650x100.nii
# Uncompressed and saved Pos_3_6_9z151y650x100_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z151y650x100_gt.nii
# Uncompressed and saved Pos_3_6_9z151y650x50.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z151y650x50.nii
# Uncompressed and saved Pos_3_6_9z151y650x50_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z151y650x50_gt.nii
# Uncompressed and saved Pos_3_6_9z152y400x300.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z152y400x300.nii
# Uncompressed and saved Pos_3_6_9z152y400x300_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z152y400x300_gt.nii
# Uncompressed and saved Pos_3_6_9z152y450x300.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z152y450x300.nii
# Uncompressed and saved Pos_3_6_9z152y450x300_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z152y450x300_gt.nii
# Uncompressed and saved Pos_3_6_9z152y550x150.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z152y550x150.nii
# Uncompressed and saved Pos_3_6_9z152y550x150_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z152y550x150_gt.nii
# Uncompressed and saved Pos_3_6_9z152y600x150.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z152y600x150.nii
# Uncompressed and saved Pos_3_6_9z152y600x150_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z152y600x150_gt.nii
# Uncompressed and saved Pos_3_6_9z153y500x250.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z153y500x250.nii
# Uncompressed and saved Pos_3_6_9z153y500x250_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z153y500x250_gt.nii
# Uncompressed and saved Pos_3_6_9z153y550x200.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z153y550x200.nii
# Uncompressed and saved Pos_3_6_9z153y550x200_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z153y550x200_gt.nii
# Uncompressed and saved Pos_3_6_9z153y550x250.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z153y550x250.nii
# Uncompressed and saved Pos_3_6_9z153y550x250_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z153y550x250_gt.nii
# Uncompressed and saved Pos_3_6_9z153y600x200.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z153y600x200.nii
# Uncompressed and saved Pos_3_6_9z153y600x200_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z153y600x200_gt.nii
# Uncompressed and saved Pos_3_6_9z153y650x150.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z153y650x150.nii
# Uncompressed and saved Pos_3_6_9z153y650x150_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z153y650x150_gt.nii
# Uncompressed and saved Pos_3_6_9z153y700x100.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z153y700x100.nii
# Uncompressed and saved Pos_3_6_9z153y700x100_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z153y700x100_gt.nii
# Uncompressed and saved Pos_3_6_9z153y700x150.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z153y700x150.nii
# Uncompressed and saved Pos_3_6_9z153y700x150_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z153y700x150_gt.nii
# Uncompressed and saved Pos_3_6_9z154y0x100.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z154y0x100.nii
# Uncompressed and saved Pos_3_6_9z154y0x100_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z154y0x100_gt.nii
# Uncompressed and saved Pos_3_6_9z154y0x150.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z154y0x150.nii
# Uncompressed and saved Pos_3_6_9z154y0x150_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z154y0x150_gt.nii
# Uncompressed and saved Pos_3_6_9z154y0x200.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z154y0x200.nii
# Uncompressed and saved Pos_3_6_9z154y0x200_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z154y0x200_gt.nii
# Uncompressed and saved Pos_3_6_9z154y0x250.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z154y0x250.nii
# Uncompressed and saved Pos_3_6_9z154y0x250_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z154y0x250_gt.nii
# Uncompressed and saved Pos_3_6_9z154y0x300.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z154y0x300.nii
# Uncompressed and saved Pos_3_6_9z154y0x300_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z154y0x300_gt.nii
# Uncompressed and saved Pos_3_6_9z154y0x350.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z154y0x350.nii
# Uncompressed and saved Pos_3_6_9z154y0x350_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z154y0x350_gt.nii
# Uncompressed and saved Pos_3_6_9z154y100x0.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z154y100x0.nii
# Uncompressed and saved Pos_3_6_9z154y100x0_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z154y100x0_gt.nii
# Uncompressed and saved Pos_3_6_9z154y100x100.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z154y100x100.nii
# Uncompressed and saved Pos_3_6_9z154y100x100_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z154y100x100_gt.nii
# Uncompressed and saved Pos_3_6_9z154y100x150.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z154y100x150.nii
# Uncompressed and saved Pos_3_6_9z154y100x150_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z154y100x150_gt.nii
# Uncompressed and saved Pos_3_6_9z154y100x200.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z154y100x200.nii
# Uncompressed and saved Pos_3_6_9z154y100x200_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z154y100x200_gt.nii
# Uncompressed and saved Pos_3_6_9z154y100x250.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z154y100x250.nii
# Uncompressed and saved Pos_3_6_9z154y100x250_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z154y100x250_gt.nii
# Uncompressed and saved Pos_3_6_9z154y100x50.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z154y100x50.nii
# Uncompressed and saved Pos_3_6_9z154y100x50_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z154y100x50_gt.nii
# Uncompressed and saved Pos_3_6_9z154y150x250.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z154y150x250.nii
# Uncompressed and saved Pos_3_6_9z154y150x250_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z154y150x250_gt.nii
# Uncompressed and saved Pos_3_6_9z154y150x300.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z154y150x300.nii
# Uncompressed and saved Pos_3_6_9z154y150x300_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z154y150x300_gt.nii
# Uncompressed and saved Pos_3_6_9z154y150x50.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z154y150x50.nii
# Uncompressed and saved Pos_3_6_9z154y150x50_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z154y150x50_gt.nii
# Uncompressed and saved Pos_3_6_9z154y200x150.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z154y200x150.nii
# Uncompressed and saved Pos_3_6_9z154y200x150_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z154y200x150_gt.nii
# Uncompressed and saved Pos_3_6_9z154y200x200.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z154y200x200.nii
# Uncompressed and saved Pos_3_6_9z154y200x200_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z154y200x200_gt.nii
# Uncompressed and saved Pos_3_6_9z154y50x100.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z154y50x100.nii
# Uncompressed and saved Pos_3_6_9z154y50x100_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z154y50x100_gt.nii
# Uncompressed and saved Pos_3_6_9z154y50x150.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z154y50x150.nii
# Uncompressed and saved Pos_3_6_9z154y50x150_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z154y50x150_gt.nii
# Uncompressed and saved Pos_3_6_9z154y50x200.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z154y50x200.nii
# Uncompressed and saved Pos_3_6_9z154y50x200_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z154y50x200_gt.nii
# Uncompressed and saved Pos_3_6_9z154y50x250.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z154y50x250.nii
# Uncompressed and saved Pos_3_6_9z154y50x250_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z154y50x250_gt.nii
# Uncompressed and saved Pos_3_6_9z154y50x300.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z154y50x300.nii
# Uncompressed and saved Pos_3_6_9z154y50x300_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z154y50x300_gt.nii
# Uncompressed and saved Pos_3_6_9z154y50x350.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z154y50x350.nii
# Uncompressed and saved Pos_3_6_9z154y50x350_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z154y50x350_gt.nii
# Uncompressed and saved Pos_3_6_9z155y100x300.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z155y100x300.nii
# Uncompressed and saved Pos_3_6_9z155y100x300_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z155y100x300_gt.nii
# Uncompressed and saved Pos_3_6_9z155y150x200.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z155y150x200.nii
# Uncompressed and saved Pos_3_6_9z155y150x200_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z155y150x200_gt.nii
# Uncompressed and saved Pos_3_6_9z155y700x50.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z155y700x50.nii
# Uncompressed and saved Pos_3_6_9z155y700x50_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z155y700x50_gt.nii
# Uncompressed and saved Pos_3_6_9z156y700x0.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z156y700x0.nii
# Uncompressed and saved Pos_3_6_9z156y700x0_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z156y700x0_gt.nii
# Uncompressed and saved Pos_3_6_9z157y650x0.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z157y650x0.nii
# Uncompressed and saved Pos_3_6_9z157y650x0_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z157y650x0_gt.nii
# Uncompressed and saved Pos_3_6_9z158y150x100.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z158y150x100.nii
# Uncompressed and saved Pos_3_6_9z158y150x100_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z158y150x100_gt.nii
# Uncompressed and saved Pos_3_6_9z158y150x150.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z158y150x150.nii
# Uncompressed and saved Pos_3_6_9z158y150x150_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z158y150x150_gt.nii
# Uncompressed and saved Pos_3_6_9z179y500x600.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z179y500x600.nii
# Uncompressed and saved Pos_3_6_9z179y500x600_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z179y500x600_gt.nii
# Uncompressed and saved Pos_3_6_9z199y550x500.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z199y550x500.nii
# Uncompressed and saved Pos_3_6_9z199y550x500_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z199y550x500_gt.nii
# Uncompressed and saved Pos_3_6_9z200y450x500.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z200y450x500.nii
# Uncompressed and saved Pos_3_6_9z200y450x500_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z200y450x500_gt.nii
# Uncompressed and saved Pos_3_6_9z200y500x500.nii.gz to 1.2_folder/Pos_3_6_9_tomogram_patches\Pos_3_6_9z200y500x500.nii
# Uncompressed and saved Pos_3_6_9z200y500x500_gt.nii.gz to 1.2_folder/Pos_3_6_9_label_patches\Pos_3_6_9z200y500x500_gt.nii

# %% [markdown]
# ### Plot Patches and Tomograms

# %%
def plot_2D_3D_patch_volumes(output_dir_3D, output_dir_2D, volume_index=0):
    # find all 3D patch volumes
    raw_files = sorted(glob.glob(os.path.join(output_dir_3D, "patch_3D_raw_y*_x*.nii")))
    label_files = sorted(glob.glob(os.path.join(output_dir_3D, "patch_3D_label_y*_x*.nii")))
    # extract the y and x coordinates from the filenames
    coordinates = []
    for raw_file in raw_files:
        filename = os.path.basename(raw_file)
        y, x = re.findall(r"_y(\d+)_x(\d+).nii", filename)[0]
        coordinates.append((int(y), int(x)))
    # sort the raw and label filenames and coordinates based on the y and x coordinates
    sorted_raw_files_and_coordinates = sorted(zip(raw_files, coordinates), key=lambda x: x[1])
    sorted_label_files_and_coordinates = sorted(zip(label_files, coordinates), key=lambda x: x[1])
    sorted_raw_files, sorted_coordinates = zip(*sorted_raw_files_and_coordinates)
    sorted_label_files, _ = zip(*sorted_label_files_and_coordinates)
    # find the index of the corresponding 3D patch file
    y_coord, x_coord = sorted_coordinates[volume_index]
    # load the specified 3D patch volume
    print(sorted_raw_files[volume_index], sorted_coordinates[volume_index], sorted_label_files[volume_index])
    raw_img = nib.load(sorted_raw_files[volume_index])
    raw_data = raw_img.get_fdata()
    label_img = nib.load(sorted_label_files[volume_index])
    label_data = label_img.get_fdata()
    # find the index of the corresponding 2D patch file
    index_2D = None
    for i, coord in enumerate(coordinates):
        if coord == (y_coord, x_coord):
            index_2D = i
            break
    if index_2D is None:
        print("Matching 2D patch file not found.")
        return
    # load the corresponding 2D raw and label patches
    raw_2Dfiles = sorted(glob.glob(os.path.join(output_dir_2D, "patch_raw_y*_x*.nii")))
    label_2Dfiles = sorted(glob.glob(os.path.join(output_dir_2D, "patch_label_y*_x*.nii")))
    # extract the y and x coordinates from the filenames
    coordinates_2D = []
    for filename in raw_2Dfiles:
        y, x = re.findall(r"_y(\d+)_x(\d+).nii", filename)[0]
        coordinates_2D.append((int(y), int(x)))
    # find the index of the corresponding 2D patch file
    index_2D = coordinates_2D.index((y_coord, x_coord))
    raw_2Ddata = nib.load(raw_2Dfiles[index_2D]).get_fdata()
    label_2Ddata = nib.load(label_2Dfiles[index_2D]).get_fdata()
    print(raw_2Dfiles[index_2D], label_2Dfiles[index_2D], (y_coord, x_coord))

    def update(z):
        # plot the 3D and 2D patch volumes
        fig, axs = plt.subplots(2, 2, figsize=(14, 14))
        axs[1, 0].imshow(raw_2Ddata, cmap='gray')
        axs[1, 0].set_title(f"Raw Patch (y={y_coord}, x={x_coord})")
        axs[1, 1].imshow(label_2Ddata, cmap='gray')
        axs[1, 1].set_title(f"Label Patch (y={y_coord}, x={x_coord})")
        axs[0, 0].imshow(raw_data[:, :, z], cmap='gray')
        axs[0, 0].set_title(f"Raw Volume (y={y_coord}, x={x_coord})")
        axs[0, 1].imshow(label_data[:, :, z], cmap="gray", vmin=0, vmax=1)
        axs[0, 1].set_title(f"Label Volume (y={y_coord}, x={x_coord})")
        plt.show()

    # create the slider and play button
    z_slider = widgets.IntSlider(min=0, max=raw_data.shape[2] - 1, step=1, value=0, description="Slice")
    play = widgets.Play(interval=500, value=0, min=0, max=raw_data.shape[2] - 1, step=1, description="Play")
    widgets.jslink((play, 'value'), (z_slider, 'value'))
    button_layout = widgets.Layout(width='80px')
    play_button = widgets.Button(description=">", layout=button_layout)
    widgets.jslink((play, 'value'), (play_button, 'disabled'))

    def on_play_button_click(b):
        if play.value == play.max:
            play.value = play.min
            play_button.description = ">"
        elif play.playing:
            play.stop()
            play_button.description = "Play"
        else:
            play.play()
            play_button.description = "Pause"

    play_button.on_click(on_play_button_click)
    display(widgets.HBox([z_slider, play, play_button]))
    interact(update, z=z_slider)
